# %% [markdown]
# ## Datacamp CapGemini
# #### Group 7

# %%
import pandas as pd
import numpy as np

from tqdm import tqdm
tqdm.pandas()

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# ### Import data

# %%
labeled_data = pd.read_csv('../data/labeled_data.csv', encoding='utf8')
unlabeled_data = pd.read_csv('../data/data_unlabeled.csv', engine='c', encoding='utf8')

# %%
labeled_data["text"].sample(20)
# Out:
# 1067                                    plenty of memory.
# 2537    you could get a gaming laptop that has gtx 105...
# 438     the s8 is great, easy to use and tons of features
# 7735    combined with the image stabilizers for the ca...
# 2982    galaxy s8 and s8+ oreo beta may end january 15...
# 8256    no improvement  in camera pixel 12 mp is less,...
# 2492    i really appreciated this streamlined process ...
# 2499    the fingerprint scanner doesn't bother me i wh...
# 5620    the x is the start of a new line where they te...
# 4809       i love that they added back expandable memory.
# 6956    the samsung galaxy line remained top in the li...
# 1415    shit dude, you might also need a vomit bucket ...
# 4705    if you are looking for a new mobile device, yo...
# 4664    its smaller than the 7s, this make it easy to ...
# 7056    had to get a new phone since i was running out...
# 8745                           the screen is really nice.
# 5082    enjoying the new features and cool gadgets tha...
# 787                                    very simple to use
# 4168                         my iphone 5 was pretty good.
# 6578    all in all, i very much enjoy this phone with ...
# Name: text, dtype: object

# %%
unlabeled_data["text"].sample(10)
# Out:
# 29729                      face unlock is not that great .
# 59483    the no home button addition was quite annoying...
# 57891                     amazing specs and image quality!
# 75434    i have own previous i phones, and when i up gr...
# 10906    only happens on first attempt, then works as e...
# 55628    stereo speakers in the phone is the most stupi...
# 23448                  my old s6 charges faster than this.
# 7646     they do need to patch the software to allow us...
# 70640    well, compared tomy previous phone (galaxy not...
# 32663     \r\n\r\n\r\nand dont compare the devices prec...
# Name: text, dtype: object

# %%
selected_classes = ['screen', 'software_bugs', 'locking_system', 'system', 'apps_update', 'battery_life_charging', 'customerservice']
labeled_data.iloc[:, 1:].loc[:, selected_classes].apply(pd.value_counts)
# Out:
#      screen  software_bugs  locking_system  system  apps_update  \
# 0.0   10681          10857           10791   10654        10915
# 1.0     316            140             206     343           82
#
#      battery_life_charging  customerservice
# 0.0                  10850            10888
# 1.0                    147              109

# %% [markdown]
# ## Feature creation

# %% [markdown]
# We start by defining our preprocessing pipeline :

# %% [markdown]
# ### Preprocessing pipeline

# %% [markdown]
# #### Pre-processing and tokenization

# %%
import regex
from nltk.tokenize import TweetTokenizer
from nltk.corpus import stopwords as stpwrds

# %%
def preprocess_text(df):
    # Remove ponctuation
    matrix = str.maketrans(",\"_;", "    ", "'’.()/-?!|:><&[]*=@%^â€™")
    df["text"] = df["text"].transform(lambda x: x.translate(matrix))
    
    # Remove bad characters
    df["text"] = df["text"].transform(lambda text: ''.join([x for x in text if ord(x)<128 or ord(x)!=25]))
    
    # Remove hashtags
    df["text"] = df["text"].map(lambda x: regex.sub('#[a-zA-Z0-9-]*', '', x))
    
    # Remove number only strings
    numbers = regex.compile('^[0-9 ]+$')
    mask = df["text"].map(lambda x: not numbers.match(x))
    df = df[mask]
    
    mask = df["text"].map(lambda x: x.strip() == '')
    df = df.loc[~mask]
    
    return df

# %%
def tokenize(df):
    # Tokenize
    tweet = TweetTokenizer(preserve_case=False, strip_handles=True, reduce_len=True)
    stopwords = set(stpwrds.words('english'))

    df["text"] = df["text"].transform(tweet.tokenize)
    
    # Remove stopwords
    df["text"] = df["text"].transform(lambda x: [token for token in x if not token in stopwords])
    
    # Remove tokens with only numbers
    numbers = regex.compile('^[0-9]{3,}$')
    df["text"] = df["text"].map(lambda x: [token for token in x if not numbers.match(token)])
    
    # Number of tokens
    df["length"] = df["text"].apply(lambda x: len(x))
    return df

# %%
# Detect language
import langdetect

def detect_lang(x):
    try: 
        return langdetect.detect(x)
    except Exception as e:
        return None

# %% [markdown]
# #### Lemmatization

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

# %%
def lemmatize(tokens):
    return [lemmatizer.lemmatize(token) for token in tokens]

# %%
import spacy
nlp = spacy.load('en', disable=['parser', 'ner'])

# %%
def spacy_lemmatize(tokens, nlp):
    doc = nlp(" ".join(tokens))
    return [token.lemma_.lower().strip() for token in doc if token.lemma_ != "-PRON-"]

# %% [markdown]
# #### Custom lemmatization

# %%
# Custom tokens
def custom_lemmatize(tokens):
    processed = []
    extend = processed.extend
    length = len(tokens)
    
    for i, token in enumerate(tokens):
        # iPhones
        if token == "x" or token == "10":
            result = ["10"]
            if i>0 and tokens[i-1] != "iphone":
                result.insert(0, "iphone")
            extend(result)
            continue
        if token in ["6", "7", "8"]:
            result = [token]
            if i>0 and tokens[i-1] != "iphone":
                result.insert(0, "iphone")
            extend(result)
            continue
        if token == "+":
            extend(["plus"])
        extend([token])
        
        # Samsung
        if token == "s8":
            result = ["S8"]
            if i>0 and tokens[i-1] != "samsung":
                result.insert(0, "samsung")
            extend(result)
            continue
        
    return processed

# %% [markdown]
# #### Bigrams

# %%
from gensim.models.phrases import Phrases, Phraser

# %%
def bigrams(column):
    phrases = Phrases(column.values.tolist())
    bigrams = Phraser(phrases)
    return list(bigrams[column.values.tolist()])

# %% [markdown]
# #### Final function

# %%
def preprocessing_pipeline(df, threshold=4):
    df = preprocess_text(df)
    df = tokenize(df)
    df['text'] = df['text'].progress_map(lambda x: spacy_lemmatize(x, nlp))
    df['text'] = df['text'].apply(custom_lemmatize)
    df['text'] = bigrams(df['text'])
    df['text'] = df['text'].apply(lambda x: [tk for tk in x if tk])
    df = df[df['text'].map(lambda x: len(x) > threshold)]
    return df

# %% [markdown]
# ### Word/sentence encoding

# %%
from sklearn.model_selection import train_test_split

# %%
X_lbl_train, X_lbl_test = train_test_split(labeled_data, test_size=0.2, random_state=42, stratify=labeled_data['issue'])

# %%
counts = X_lbl_train.iloc[:, 1:].loc[:, selected_classes].apply(pd.value_counts)
for cat, values in counts.iteritems():
    print("{} - {:.2%} positives".format(cat, values[1]/values[0]))
# Out:
# screen - 3.08% positives
# software_bugs - 1.31% positives
# locking_system - 1.79% positives
# system - 3.14% positives
# apps_update - 0.80% positives
# battery_life_charging - 1.39% positives
# customerservice - 1.08% positives

# %%
X_lbl_train = preprocessing_pipeline(X_lbl_train)
X_lbl_test = preprocessing_pipeline(X_lbl_test)
y_lbl_train = X_lbl_train['issue']
y_lbl_test = X_lbl_test['issue']
# Out:
# 100%|██████████| 8788/8788 [00:24<00:00, 352.03it/s]
# 100%|██████████| 2197/2197 [00:06<00:00, 362.03it/s]

# %% [markdown]
# #### Doc2Vec (what we use)

# %%
from gensim.models import Doc2Vec
from gensim.models.doc2vec import TaggedDocument

# %%
def get_docs(sources):
    for label, source in sources.items():
        for i, tokens in source.iteritems():
            yield TaggedDocument(words=tokens, tags=["{}_{}".format(label, i)])

# %%
# Train with train data
sources = {
    'TRAIN': X_lbl_train["text"]
}

reviews = list(get_docs(sources))

# %%
model = Doc2Vec(size=500, window=15, min_count=10, workers=10)
model.build_vocab(reviews)
model.train(reviews, epochs=20, total_examples=model.corpus_count)

# %%
def d2v(model, data, infer=True): 
    if infer:
        vectors = [model.infer_vector(review) for review in data.values.tolist()]
    else:
        vectors = [model["TRAIN_{}".format(i)] for i in data.index.values.tolist()]
        
    return pd.DataFrame(vectors, index=data.index, columns=["dim_{}".format(i) for i in range(model.vector_size)])

# %%
X_lbl_train_d2v = d2v(model, X_lbl_train['text'], infer=False)
X_lbl_test_d2v = d2v(model, X_lbl_test['text'], infer=True)

# %% [markdown]
# #### TF-IDF

# %%
import itertools
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
# Get vocabulary
vocab = list(
    set(itertools.chain(*X_lbl_train['text'].tolist()))|
    set(itertools.chain(*X_lbl_test['text'].tolist()))|
    set(itertools.chain(*X_unlbl['text'].tolist()))
)
vocab_dict = dict((y, x) for x, y in enumerate(vocab))

# %%
model = TfidfVectorizer(ngram_range=(1,3), use_idf=True, vocabulary=vocab_dict)

# %%
X_lbl_train = model.fit_transform(X_lbl_train['text'].apply(lambda x: " ".join(x)).values.tolist())
X_lbl_test = model.transform(X_lbl_test['text'].apply(lambda x: " ".join(x)).values.tolist())
X_unlbl = model.transform(X_unlbl['text'].apply(lambda x: " ".join(x)).values.tolist())

# %% [markdown]
# ### Semi-supervised learning

# %% [markdown]
# #### XGBoost classification without label propagation

# %%
from xgboost import XGBClassifier
from sklearn.metrics import classification_report

# %%
clf = XGBClassifier(max_depth=20, 
                    n_estimators=750, 
                    min_child_weight=3, 
                    scale_pos_weight=2,
                    learning_rate=0.05, 
                    max_delta_step=0.5,
                    gamma=0.01,
                    colsample_bytree=0.8,
                    n_jobs=-1)

# %%
clf.fit(X_lbl_train_d2v, y_lbl_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=0.8, gamma=0.01, learning_rate=0.05,
#        max_delta_step=0.5, max_depth=20, min_child_weight=3, missing=None,
#        n_estimators=750, n_jobs=-1, nthread=None,
#        objective='binary:logistic', random_state=0, reg_alpha=0,
#        reg_lambda=1, scale_pos_weight=2, seed=None, silent=True,
#        subsample=1)

# %%
print(classification_report(y_lbl_test, clf.predict(X_lbl_test_d2v)))
# Out:
#              precision    recall  f1-score   support
#
#         0.0       0.86      0.90      0.88      1290
#         1.0       0.32      0.25      0.28       253
#
# avg / total       0.77      0.79      0.78      1543
# /usr/local/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %% [markdown]
# #### Prediction on unlabeled data (WIP - not used for the final prediction due to poor results)

# %% [markdown]
# First we use our classifier to predict issues on the unlabeled data :

# %%
X_unlbl = preprocessing_pipeline(unlabeled_data)
# Out:
# 100%|██████████| 84330/84330 [03:52<00:00, 363.36it/s]

# %%
X_unlbl_d2v = d2v(model, X_unlbl['text'], infer=True)

# %%
issue_predictions = pd.DataFrame(clf.predict_proba(X_unlbl_d2v)[:, 1], index=X_unlbl_d2v.index)

unlabeled_data['xgb_issue_prob'] = issue_predictions
# Drop rows if no issue proba
unlabeled_data = unlabeled_data.dropna(subset=['xgb_issue_prob'])
# Predict binary output according to a threshold
unlabeled_data['xgb_issue'] = unlabeled_data['xgb_issue_prob'].apply(lambda x: x > 0.4).map(int)

# %%
unlabeled_data['xgb_issue'].value_counts()

# %% [markdown]
# Then we perform sentiment analysis in order to detect false positives :

# %%
from textblob import TextBlob

# %%
def sentiment(text):
    try:
        return TextBlob(text).sentiment.polarity
    except:
        return None

# %%
unlabeled_data['sentiment'] = unlabeled_data["text"].progress_map(sentiment)

# %% [markdown]
# We cross results to spot weird matches :

# %%
def combine_preds(row, prob_col_name="xgb_issue", sentiment_col_name="sentiment"):
    return int(row[prob_col_name] == 1 and row[sentiment_col_name] <= 0)

unlabeled_data['issue'] = unlabeled_data.apply(combine_preds, axis=1)

# %%
unlabeled_data['issue'].value_counts()

# %% [markdown]
# #### Retrain

# %%
clf_all = XGBClassifier(max_depth=8, 
                        n_estimators=750, 
                        min_child_weight=3, 
                        scale_pos_weight=2,
                        learning_rate=0.05, 
                        max_delta_step=0.5,
                        gamma=0.01,
                        n_jobs=-1)

# %%
X_all = pd.concat([X_lbl_train_d2v, X_unlbl_d2v])
y_all = pd.concat([y_lbl_train, unlabeled_data['issue']])

# %%
clf.fit(X_all, y_all)

# %%
print(classification_report(y_lbl_test, clf.predict(X_lbl_test_d2v)))

# %% [markdown]
# ### Hackathon : multi-~~label~~ class problem

# %% [markdown]
# We decided to reduce the classification problem to a multiclass one :

# %%
selected_classes = ['screen', 'software_bugs', 'locking_system', 'system', 'apps_update', 'battery_life_charging', 'customerservice']

# %% [markdown]
# We create a new `issue` indicator column on the class subset and merge all classes dummy variables :

# %%
X_lbl_train['issue'] = X_lbl_train.loc[:, selected_classes].apply(lambda x: int(x.any()), axis=1)
X_lbl_test['issue'] = X_lbl_test.loc[:, selected_classes].apply(lambda x: int(x.any()), axis=1)

# %%
def encode_class(row):
    if row['issue'] == 1:
        issue_name = row.idxmax(1)
        return selected_classes.index(issue_name)+1
    return 0

# %%
y_lbl_train = X_lbl_train.loc[:, selected_classes + ['issue']].apply(encode_class, axis=1)
y_lbl_test = X_lbl_test.loc[:, selected_classes + ['issue']].apply(encode_class, axis=1)

# %% [markdown]
# We train the classifier on this categorical vector :

# %%
clf = XGBClassifier(max_depth=8, 
                    n_estimators=750, 
                    objective='multi:softprob',
                    min_child_weight=3, 
                    scale_pos_weight=2,
                    learning_rate=0.05, 
                    max_delta_step=0.5,
                    gamma=0.01,
                    n_jobs=-1)

# %%
clf.fit(X_lbl_train_d2v, y_lbl_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0.01, learning_rate=0.05,
#        max_delta_step=0.5, max_depth=8, min_child_weight=3, missing=None,
#        n_estimators=750, n_jobs=-1, nthread=None,
#        objective='multi:softprob', random_state=0, reg_alpha=0,
#        reg_lambda=1, scale_pos_weight=2, seed=None, silent=True,
#        subsample=1)

# %%
print(classification_report(y_lbl_test, clf.predict(X_lbl_test_d2v)))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.88      0.96      0.92      1348
#           1       0.25      0.29      0.27        48
#           2       1.00      0.04      0.08        23
#           3       0.00      0.00      0.00        39
#           4       0.00      0.00      0.00        54
#           5       0.00      0.00      0.00         6
#           6       0.27      0.19      0.22        16
#           7       0.00      0.00      0.00         9
#
# avg / total       0.80      0.85      0.82      1543
# /usr/local/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %% [markdown]
# ### Prediction on test data

# %%
test_data = pd.read_csv('../data/test_data.csv', encoding='utf8')

# %%
X_test = preprocessing_pipeline(test_data)
X_test_d2v = d2v(model, X_test['text'], infer=True)
# Out:
# 100%|██████████| 2513/2513 [00:06<00:00, 365.16it/s]

# %%
predictions = pd.DataFrame(clf.predict_proba(X_test_d2v),
                           index=X_test.index)
predictions = predictions.drop(columns=[0])
predictions.columns = selected_classes

# We set a low threshold in order to maximize the recall
predictions = predictions.applymap(lambda x: int(x>0.2))

# %%
X_y_test = pd.concat([test_data['text'], predictions], axis=1)
X_y_test = X_y_test.fillna(0)
X_y_test['issue'] = X_y_test.iloc[:, 1:].apply(lambda x: int(x.any()), axis=1)

# %%
# Preview of the results
mask = X_y_test.iloc[:, 2:].apply(lambda x: x.any(), axis=1)
X_y_test[mask]
# Out:
#                                                    text  screen  \
# 32    screen slippery hard to hold due to curved edg...     1.0
# 63    the screen looks so much smaller when you firs...     1.0
# 69    my friends week old s8 has already found a poi...     1.0
# 79    i wasnt sure id like the curved edge but ive g...     1.0
# 120   is lighter and the screen resolution is much b...     1.0
# 146   end it has everything you want to head and it ...     1.0
# 158   the curved glass has taken me awhile to get us...     1.0
# 173   less than 2 weeks in and theres a small scratc...     1.0
# 183   it feels fragile in my hand it probably isnt r...     1.0
# 202              it streams shows easily to my smart tv     1.0
# 206   the samsung  galaxy s8 64gb  orchid gray sprin...     1.0
# 261   yes  its longer  but its so thin and rounded e...     1.0
# 316   i didnt like what i was missing in the 6 so i ...     0.0
# 362   like the curved sides makes the screen seem la...     1.0
# 377   the curved screen makes it nearly impossible t...     1.0
# 408   the galaxy s8 is a good phone  but freezes and...     1.0
# 412   i have big hands and can use the finger scanne...     1.0
# 413   i think its a bit too tall for comfort inside ...     1.0
# 417   i charge the phone every 3 days i put the phon...     0.0
# 433   and actually  even though its smaller  the scr...     1.0
# 438               love the thin profile and full screen     1.0
# 461   some of the things i liked were that the scree...     1.0
# 462   the fact that certain apps came preloaded was ...     0.0
# 469   i dont want to live paranoid of dropping my ph...     1.0
# 490   the samsung galaxy s8 was the first smartphone...     1.0
# 499   no more looking back  samsung galaxy s8 is a g...     1.0
# 502   its fast and easy to use with great color oled...     1.0
# 580   i like the feel and slimness of the phone even...     1.0
# 584   the battery lasts much longer than the s6 edge...     1.0
# 590   the graphics are a step up from my s5 but it i...     0.0
# ...                                                 ...     ...
# 2209  smaller profile  bigger beautiful screen and fast     1.0
# 2210  got it with zagg screen protector and the appl...     1.0
# 2218  bought the phone outright instead of relying o...     0.0
# 2248  first  if youre familiar with iphones you will...     0.0
# 2255  the extra body youre used to with the top and ...     1.0
# 2257  as apps slowly start to update and utilize the...     1.0
# 2265  the answer for that is pretty simpleinvest in ...     1.0
# 2266  i personally almost always use a case so it do...     1.0
# 2284  open it up and everything looks good at first ...     1.0
# 2285  a very very small scratch or crack under the s...     1.0
# 2303  but apple still put 5v charger in the box whic...     0.0
# 2318  i unlock a lot of my apps with that function a...     0.0
# 2354  the home screen looks beautiful and the oled d...     1.0
# 2357  snapchat users will like that it can detect fa...     1.0
# 2359  it feels very much like the iphone 8 in size a...     1.0
# 2363  granted  it doesnt charge as fast  but the con...     0.0
# 2364  cons\r\r\r\n\r\r\r\n displays size  its advert...     1.0
# 2366  the notch doesnt bother me nor does the lack o...     0.0
# 2380  the downside the screen maybe the same size as...     1.0
# 2410  no more fumbling because of wet or dirty finge...     0.0
# 2445  it took me a little getting used to on where e...     0.0
# 2448  the screen also is quite stellar looking  much...     1.0
# 2453  the screen is beautiful but it has an android ...     1.0
# 2464       wish it had a bigger screen  but runs smooth     1.0
# 2477  the curved edges of the display work poorly wi...     1.0
# 2479  this means that moisture can get between the p...     1.0
# 2480  this also makes the phone is less responsive t...     1.0
# 2481  furthermore  the screen isnt protected as well...     1.0
# 2482  this lack of edge protection allowed a short d...     1.0
# 2508  im not very excited about the  edge  feature  ...     1.0
#
#       software_bugs  locking_system  system  apps_update  \
# 32              0.0             0.0     0.0          0.0
# 63              0.0             0.0     0.0          0.0
# 69              0.0             0.0     0.0          0.0
# 79              0.0             0.0     0.0          0.0
# 120             0.0             0.0     0.0          0.0
# 146             0.0             0.0     0.0          0.0
# 158             0.0             0.0     0.0          0.0
# 173             0.0             0.0     0.0          0.0
# 183             0.0             0.0     0.0          0.0
# 202             0.0             0.0     0.0          0.0
# 206             0.0             0.0     0.0          0.0
# 261             0.0             0.0     0.0          0.0
# 316             0.0             1.0     0.0          0.0
# 362             0.0             0.0     0.0          0.0
# 377             0.0             0.0     0.0          0.0
# 408             0.0             0.0     0.0          0.0
# 412             0.0             0.0     0.0          0.0
# 413             0.0             0.0     0.0          0.0
# 417             0.0             0.0     0.0          0.0
# 433             0.0             0.0     0.0          0.0
# 438             0.0             0.0     0.0          0.0
# 461             0.0             0.0     0.0          0.0
# 462             0.0             1.0     0.0          0.0
# 469             0.0             0.0     0.0          0.0
# 490             0.0             0.0     0.0          0.0
# 499             0.0             0.0     0.0          0.0
# 502             0.0             0.0     0.0          0.0
# 580             0.0             0.0     0.0          0.0
# 584             0.0             0.0     0.0          0.0
# 590             0.0             0.0     0.0          0.0
# ...             ...             ...     ...          ...
# 2209            0.0             0.0     0.0          0.0
# 2210            0.0             0.0     0.0          0.0
# 2218            0.0             0.0     0.0          0.0
# 2248            0.0             1.0     0.0          0.0
# 2255            0.0             0.0     0.0          0.0
# 2257            0.0             0.0     0.0          0.0
# 2265            0.0             0.0     0.0          0.0
# 2266            0.0             0.0     0.0          0.0
# 2284            0.0             0.0     0.0          0.0
# 2285            0.0             0.0     0.0          0.0
# 2303            0.0             0.0     0.0          0.0
# 2318            0.0             1.0     0.0          0.0
# 2354            0.0             0.0     0.0          0.0
# 2357            0.0             0.0     0.0          0.0
# 2359            0.0             0.0     0.0          0.0
# 2363            0.0             0.0     0.0          0.0
# 2364            0.0             0.0     0.0          0.0
# 2366            0.0             1.0     0.0          0.0
# 2380            0.0             0.0     0.0          0.0
# 2410            0.0             1.0     0.0          0.0
# 2445            0.0             1.0     0.0          0.0
# 2448            0.0             0.0     0.0          0.0
# 2453            0.0             0.0     0.0          0.0
# 2464            0.0             0.0     0.0          0.0
# 2477            0.0             0.0     0.0          0.0
# 2479            0.0             0.0     0.0          0.0
# 2480            0.0             0.0     0.0          0.0
# 2481            0.0             0.0     0.0          0.0
# 2482            0.0             0.0     0.0          0.0
# 2508            0.0             0.0     0.0          0.0
#
#       battery_life_charging  customerservice  issue
# 32                      0.0              0.0      1
# 63                      0.0              0.0      1
# 69                      0.0              0.0      1
# 79                      0.0              0.0      1
# 120                     0.0              0.0      1
# 146                     0.0              0.0      1
# 158                     0.0              0.0      1
# 173                     0.0              0.0      1
# 183                     0.0              0.0      1
# 202                     0.0              0.0      1
# 206                     0.0              0.0      1
# 261                     0.0              0.0      1
# 316                     0.0              0.0      1
# 362                     0.0              0.0      1
# 377                     0.0              0.0      1
# 408                     0.0              0.0      1
# 412                     0.0              0.0      1
# 413                     0.0              0.0      1
# 417                     1.0              0.0      1
# 433                     0.0              0.0      1
# 438                     0.0              0.0      1
# 461                     0.0              0.0      1
# 462                     0.0              0.0      1
# 469                     0.0              0.0      1
# 490                     0.0              0.0      1
# 499                     0.0              0.0      1
# 502                     0.0              0.0      1
# 580                     0.0              0.0      1
# 584                     0.0              0.0      1
# 590                     1.0              0.0      1
# ...                     ...              ...    ...
# 2209                    0.0              0.0      1
# 2210                    0.0              0.0      1
# 2218                    0.0              1.0      1
# 2248                    0.0              0.0      1
# 2255                    0.0              0.0      1
# 2257                    0.0              0.0      1
# 2265                    0.0              0.0      1
# 2266                    0.0              0.0      1
# 2284                    0.0              0.0      1
# 2285                    0.0              0.0      1
# 2303                    1.0              0.0      1
# 2318                    0.0              0.0      1
# 2354                    0.0              0.0      1
# 2357                    0.0              0.0      1
# 2359                    0.0              0.0      1
# 2363                    1.0              0.0      1
# 2364                    0.0              0.0      1
# 2366                    0.0              0.0      1
# 2380                    0.0              0.0      1
# 2410                    0.0              0.0      1
# 2445                    0.0              0.0      1
# 2448                    0.0              0.0      1
# 2453                    0.0              0.0      1
# 2464                    0.0              0.0      1
# 2477                    0.0              0.0      1
# 2479                    0.0              0.0      1
# 2480                    0.0              0.0      1
# 2481                    0.0              0.0      1
# 2482                    0.0              0.0      1
# 2508                    0.0              0.0      1
#
# [173 rows x 9 columns]

# %%
# Save to disk
X_y_test.to_csv('../data/test_final.csv')
X_y_test[mask].to_csv('../data/test_issues_final.csv')

# %% [markdown]
# ### Prediction on the unlabeled data

# %%
predictions = pd.DataFrame(clf.predict_proba(X_unlbl_d2v),
                           index=X_unlbl.index)
predictions = predictions.drop(columns=[0])
predictions.columns = selected_classes

# We set a low threshold in order to maximize the recall
predictions = predictions.applymap(lambda x: int(x>0.2))

# %%
X_y_unlbl = pd.concat([unlabeled_data['text'], predictions], axis=1)
X_y_unlbl = X_y_unlbl.fillna(0)
X_y_unlbl['issue'] = X_y_unlbl.iloc[:, 1:].apply(lambda x: int(x.any()), axis=1)

# %%
counts = X_y_unlbl.loc[X_y_unlbl['issue'] == 1, :].iloc[:, 1:-1].apply(pd.value_counts)

# %%
for col, values in counts.iteritems():
    print('Feature category: {}'.format(col))
    for i, v in values.iteritems():
        print("{} - {}".format("No" if i == 0 else "Yes", v))
# Out:
# Feature category: screen
# No - 1336
# Yes - 4305
# Feature category: software_bugs
# No - 5577
# Yes - 64
# Feature category: locking_system
# No - 5056
# Yes - 585
# Feature category: system
# No - 5502
# Yes - 139
# Feature category: apps_update
# No - 5597
# Yes - 44
# Feature category: battery_life_charging
# No - 5041
# Yes - 600
# Feature category: customerservice
# No - 5598
# Yes - 43

# %%
mask = X_y_unlbl.iloc[:, 1:-1].apply(lambda x: x.any(), axis=1)
X_y_unlbl[mask]
# Out:
#                                                     text  screen  \
# 52     take the screen ratio into account and do a go...     1.0
# 59     i just wish they kept the led notice lights wh...     0.0
# 61     you should download the google keyboard  i kep...     0.0
# 71     a lightning cable is only useful within the ti...     1.0
# 109    the phone is all i expected and more  out of t...     1.0
# 117    id rather have the larger screen and resolutio...     1.0
# 131    going to miss the home button at the bottom of...     0.0
# 142    designed with the most durable glass ever in a...     1.0
# 143    designed with the most durable glass ever in a...     1.0
# 157    it look a few uses to get use to the way this ...     1.0
# 169     case for s8 plus bible verse for girls muqr s...     1.0
# 186    great screen size but the act phone is still a...     1.0
# 189    no worries about its size  the screen is so in...     1.0
# 232    has a long screen  charges fast  keeps its cha...     0.0
# 255       that tweak should be renamed  burn  baby burn      1.0
# 266    if i see its red  ill turn on low power mode a...     1.0
# 268         wow your hands make the iphone 8 look big xd     1.0
# 288    essentially  copying a face takes effort and i...     1.0
# 292    on wp  the face id is always on standby and is...     0.0
# 296    the inference engine also allows face id to  l...     0.0
# 318    i also own a ph1 and was eager to compare it  ...     1.0
# 336    apple loop three new iphones revealed serious ...     0.0
# 337      youtube is a media app like music  spotify  etc     0.0
# 347    when i swipe on a lock screen notification cur...     0.0
# 350     \r\n\r\n\r\njudging by the comment itself  it...     1.0
# 390    note i could customize the mobile hotspot name...     1.0
# 405    for instance  the edge screen has been a nuisa...     1.0
# 412    while this means that it can better fit in pla...     1.0
# 415    this means that 11 of the screen is wasted on ...     1.0
# 418     forbes apple loop three new iphones revealed ...     0.0
# ...                                                  ...     ...
# 83782  are you telling me you really believe glass pr...     1.0
# 83813  i always had an apple phone so this one was so...     1.0
# 83815  does everthing good and the screen is just ama...     1.0
# 83823  both has blueish screen  only difference is fo...     1.0
# 83829  you basically just shown ways to fix every  is...     1.0
# 83895  this is much faster  battery last much longer ...     1.0
# 83897  in order to use google voice in facebook messe...     0.0
# 83898  i have to click the little icon on the bottom ...     1.0
# 83900  and the button for bixby is right in the way s...     0.0
# 83926  having such a big battery with a powerful chip...     0.0
# 83957  this phone only keeps a charge for a maximum o...     0.0
# 83976  i could notice no big advancements and not hav...     1.0
# 84014     i guess they all break if theyre made of glass     1.0
# 84016  its not a design flaw  theyre not made of bull...     1.0
# 84020            459 smaller a10 chip f9tooijf ballsack      1.0
# 84047  or that the curved screen makes it stupidly ha...     1.0
# 84065  a sqare screen or icons in the lower part och ...     1.0
# 84139  i find that cases i use the samsung clear case...     1.0
# 84140  programming several fingerprints for the same ...     0.0
# 84173  apple loop three new iphones revealed serious ...     0.0
# 84203  my s5 lasted 3 years without a scratch and thi...     1.0
# 84210  a couple of  accidental  drops and the screen ...     1.0
# 84224  its the same battery  but the s8 has a bigger ...     1.0
# 84280  gotta tell youafter the  iphonex the screen lo...     1.0
# 84287  it is difficult to touch the farthest keys on ...     1.0
# 84293  its called white balance color temperature war...     1.0
# 84299  the loss of the physical buttons on the bottom...     0.0
# 84332  i mean the ai features do look cool but they w...     1.0
# 84339  ive actually done research on the back camera ...     1.0
# 84354  i really like the new charger usb3 and how fas...     0.0
#
#        software_bugs  locking_system  system  apps_update  \
# 52               0.0             0.0     0.0          0.0
# 59               0.0             1.0     0.0          0.0
# 61               0.0             1.0     0.0          0.0
# 71               0.0             0.0     0.0          0.0
# 109              0.0             0.0     0.0          0.0
# 117              0.0             0.0     0.0          0.0
# 131              0.0             1.0     0.0          0.0
# 142              0.0             0.0     0.0          0.0
# 143              0.0             0.0     0.0          0.0
# 157              0.0             0.0     0.0          0.0
# 169              0.0             0.0     0.0          0.0
# 186              0.0             0.0     0.0          0.0
# 189              0.0             0.0     0.0          0.0
# 232              0.0             0.0     0.0          0.0
# 255              0.0             0.0     0.0          0.0
# 266              0.0             0.0     0.0          0.0
# 268              0.0             0.0     0.0          0.0
# 288              0.0             0.0     0.0          0.0
# 292              0.0             1.0     0.0          0.0
# 296              0.0             1.0     0.0          0.0
# 318              0.0             0.0     0.0          0.0
# 336              0.0             0.0     0.0          0.0
# 337              0.0             0.0     0.0          1.0
# 347              0.0             1.0     1.0          0.0
# 350              0.0             0.0     0.0          0.0
# 390              0.0             0.0     0.0          0.0
# 405              0.0             0.0     0.0          0.0
# 412              0.0             0.0     0.0          0.0
# 415              0.0             0.0     0.0          0.0
# 418              0.0             0.0     0.0          0.0
# ...              ...             ...     ...          ...
# 83782            0.0             0.0     0.0          0.0
# 83813            0.0             0.0     0.0          0.0
# 83815            0.0             0.0     0.0          0.0
# 83823            0.0             0.0     0.0          0.0
# 83829            1.0             0.0     0.0          0.0
# 83895            0.0             0.0     0.0          0.0
# 83897            0.0             1.0     0.0          0.0
# 83898            0.0             1.0     0.0          0.0
# 83900            0.0             1.0     0.0          0.0
# 83926            0.0             0.0     0.0          0.0
# 83957            0.0             0.0     0.0          0.0
# 83976            0.0             0.0     0.0          0.0
# 84014            0.0             0.0     0.0          0.0
# 84016            0.0             0.0     0.0          0.0
# 84020            0.0             0.0     0.0          0.0
# 84047            0.0             0.0     0.0          0.0
# 84065            0.0             0.0     0.0          0.0
# 84139            0.0             0.0     0.0          0.0
# 84140            0.0             1.0     0.0          0.0
# 84173            0.0             0.0     0.0          0.0
# 84203            0.0             0.0     0.0          0.0
# 84210            0.0             0.0     0.0          0.0
# 84224            0.0             0.0     0.0          0.0
# 84280            0.0             0.0     0.0          0.0
# 84287            0.0             0.0     0.0          0.0
# 84293            0.0             0.0     0.0          0.0
# 84299            0.0             1.0     0.0          0.0
# 84332            0.0             0.0     0.0          0.0
# 84339            0.0             0.0     0.0          0.0
# 84354            0.0             0.0     0.0          0.0
#
#        battery_life_charging  customerservice  issue
# 52                       0.0              0.0      1
# 59                       0.0              0.0      1
# 61                       0.0              0.0      1
# 71                       0.0              0.0      1
# 109                      0.0              0.0      1
# 117                      0.0              0.0      1
# 131                      0.0              0.0      1
# 142                      0.0              0.0      1
# 143                      0.0              0.0      1
# 157                      0.0              0.0      1
# 169                      0.0              0.0      1
# 186                      0.0              0.0      1
# 189                      0.0              0.0      1
# 232                      1.0              0.0      1
# 255                      0.0              0.0      1
# 266                      0.0              0.0      1
# 268                      0.0              0.0      1
# 288                      0.0              0.0      1
# 292                      0.0              0.0      1
# 296                      0.0              0.0      1
# 318                      0.0              0.0      1
# 336                      1.0              0.0      1
# 337                      0.0              0.0      1
# 347                      0.0              0.0      1
# 350                      0.0              0.0      1
# 390                      0.0              0.0      1
# 405                      0.0              0.0      1
# 412                      0.0              0.0      1
# 415                      0.0              0.0      1
# 418                      1.0              0.0      1
# ...                      ...              ...    ...
# 83782                    0.0              0.0      1
# 83813                    0.0              0.0      1
# 83815                    0.0              0.0      1
# 83823                    0.0              0.0      1
# 83829                    0.0              0.0      1
# 83895                    0.0              0.0      1
# 83897                    0.0              0.0      1
# 83898                    0.0              0.0      1
# 83900                    0.0              0.0      1
# 83926                    1.0              0.0      1
# 83957                    1.0              0.0      1
# 83976                    0.0              0.0      1
# 84014                    0.0              0.0      1
# 84016                    0.0              0.0      1
# 84020                    0.0              0.0      1
# 84047                    0.0              0.0      1
# 84065                    0.0              0.0      1
# 84139                    0.0              0.0      1
# 84140                    0.0              0.0      1
# 84173                    1.0              0.0      1
# 84203                    0.0              0.0      1
# 84210                    0.0              0.0      1
# 84224                    0.0              0.0      1
# 84280                    0.0              0.0      1
# 84287                    0.0              0.0      1
# 84293                    0.0              0.0      1
# 84299                    0.0              0.0      1
# 84332                    0.0              0.0      1
# 84339                    0.0              0.0      1
# 84354                    1.0              0.0      1
#
# [5641 rows x 9 columns]

# %%
X_y_unlbl.to_csv('../data/propagation_unlbl_final.csv')
X_y_unlbl[mask].to_csv('../data/unlbl_issues_final.csv')
